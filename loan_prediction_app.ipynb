# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\kshit\anaconda3\lib\site-packages (1.29.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: altair<6,>=4.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (4.24.1)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (4.5.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\kshit\appdata\roaming\python\python311\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\kshit\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\kshit\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kshit\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\kshit\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\kshit\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kshit\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\kshit\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kshit\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\kshit\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kshit\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kshit\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kshit\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kshit\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kshit\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kshit\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: tzdata in c:\users\kshit\anaconda3\lib\site-packages (from tzlocal<6,>=1.1->streamlit) (2023.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kshit\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kshit\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kshit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kshit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)

# %%
import streamlit as st
import numpy as np
import pickle  # Assuming the model is saved as a pickle file

# Define the category mapping
category_mapping = {
    "Gender": {"male": 1, "female": 0}, 
    "Married": {"yes": 1, "no": 0},
    "Dependents": {"0": 0, "1": 1, "2": 2, "3+": 3},
    "Education": {"graduate": 0, "not graduate": 1},
    "Self_Employed": {"no": 0, "yes": 1},
    "Property_Area": {"semiurban": 0, "urban": 1, "rural": 2},  
}

# Function to preprocess text input
def preprocess_text_input(text_data):
    numerical_data = []
    keys = ["Gender", "Married", "Dependents", "Education", "Self_Employed", "Property_Area"]
    for key, value in zip(keys, text_data):
        if value in category_mapping.get(key, {}):  
            numerical_data.append(category_mapping[key][value])
        else:
            numerical_data.append(0)  
    return np.asarray(numerical_data)

# Load the trained model
# Assuming the model is saved in a file named 'loan_model.pkl'
with open('loan status prediction.sav', 'rb') as file:
    model = pickle.load(file)

# Streamlit UI
st.title("Loan Prediction App")

# Collect text input
gender = st.selectbox("Gender", ["male", "female"])
married = st.selectbox("Married", ["yes", "no"])
dependents = st.selectbox("Dependents", ["0", "1", "2", "3+"])
education = st.selectbox("Education", ["graduate", "not graduate"])
self_employed = st.selectbox("Self Employed", ["yes", "no"])
property_area = st.selectbox("Property Area", ["semiurban", "urban", "rural"])

# Collect numerical input
applicant_income = st.number_input("Applicant Income", min_value=0)
coapplicant_income = st.number_input("Coapplicant Income", min_value=0)
loan_amount = st.number_input("Loan Amount", min_value=0)
loan_amount_term = st.number_input("Loan Amount Term", min_value=0)

# Button for prediction
if st.button("Predict Loan Status"):
    # Preprocess text input
    text_input = [gender, married, dependents, education, self_employed, property_area]
    preprocessed_text_input = preprocess_text_input(text_input)

    # Combine categorical and numerical data in the specified order
    combined_data = np.concatenate((
        preprocessed_text_input[:5],  # Gender, Married, Dependents, Education, Self_Employed
        np.array([applicant_income, coapplicant_income, loan_amount, loan_amount_term]),  # ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term
        preprocessed_text_input[5:]   # Property_Area
    ))

    # Reshape data for the model
    input_data = combined_data.reshape(1, -1)

    # Make prediction
    prediction = model.predict(input_data)

    # Display the prediction result
    if prediction == 1:
        st.success('Predicted Loan Status: Yes')
    else:
        st.error('Predicted Loan Status: No')
# Out:
# 2024-06-24 10:25:24.404
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\kshit\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
